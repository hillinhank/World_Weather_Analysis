# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Users/user/Desktop/Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat      Lng  Max Temp  Humidity  \
# 0        0        Bonfim      BR   3.0833 -59.9500     82.06        67
# 1        1      Thompson      CA  55.7435 -97.8558     19.56        45
# 2        2       Formiga      BR -20.4644 -45.4264     65.17        77
# 3        3    Ust-Tsilma      RU  65.4410  52.1498     31.10        89
# 4        4  Longyearbyen      SJ  78.2186  15.6401      8.44        61
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.30     overcast clouds
# 1          20       16.11          few clouds
# 2          48        5.32    scattered clouds
# 3         100        4.29     overcast clouds
# 4          75       11.50          light snow

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is your desired minimum temperature for your trip? "))
max_temp = float(input("What is your desired maximum temperature for your trip? "))
# Out:
# What is your desired minimum temperature for your trip? 55
# What is your desired maximum temperature for your trip? 95

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
ideal_city_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) &
                                       (city_data_df["Max Temp"] >= min_temp)]
ideal_city_df.head(10)
# Out:
#     City_ID               City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0             Bonfim      BR   3.0833  -59.9500     82.06        67
# 2         2            Formiga      BR -20.4644  -45.4264     65.17        77
# 6         6             Viedma      AR -40.8135  -62.9967     67.93        45
# 8         8        Antofagasta      CL -23.6500  -70.4000     61.88        89
# 10       10    Bambous Virieux      MU -20.3428   57.7575     75.45        73
# 12       12  Placido De Castro      BR -10.3353  -67.1856     74.46        98
# 13       13          Busselton      AU -33.6500  115.3333     68.56        50
# 14       14          Carnarvon      AU -24.8667  113.6333     68.07        94
# 17       17       Puerto Ayora      EC  -0.7393  -90.3518     72.37        89
# 18       18           Charagua      BO -19.8000  -63.2167     73.71        76
#
#     Cloudiness  Wind Speed Current Description
# 0          100        5.30     overcast clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
ideal_city_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                2
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
drop_df = ideal_city_df.dropna()
drop_df
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0           Bonfim      BR   3.0833  -59.9500     82.06        67
# 2          2          Formiga      BR -20.4644  -45.4264     65.17        77
# 6          6           Viedma      AR -40.8135  -62.9967     67.93        45
# 8          8      Antofagasta      CL -23.6500  -70.4000     61.88        89
# 10        10  Bambous Virieux      MU -20.3428   57.7575     75.45        73
# ..       ...              ...     ...      ...       ...       ...       ...
# 666      666       Nageshwari      BD  25.9377   89.7148     77.40        80
# 667      667         Inverell      AU -29.7833  151.1167     71.67        49
# 668      668            Mulki      IN  13.1000   74.8000     81.68        89
# 669      669         Vung Tau      VN  10.3460  107.0843     83.62        77
# 670      670      Farafangana      MG -22.8167   47.8333     72.54        89
#
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 2             Formiga      BR     65.17    scattered clouds -20.4644
# 6              Viedma      AR     67.93     overcast clouds -40.8135
# 10    Bambous Virieux      MU     75.45    scattered clouds -20.3428
# 12  Placido De Castro      BR     74.46     overcast clouds -10.3353
# 13          Busselton      AU     68.56          light rain -33.6500
# 14          Carnarvon      AU     68.07    scattered clouds -24.8667
# 17       Puerto Ayora      EC     72.37       broken clouds  -0.7393
# 18           Charagua      BO     73.71    scattered clouds -19.8000
# 19             Atuona      PF     79.07          few clouds  -9.8000
# 20           Buchanan      LR     75.72     overcast clouds   5.8808
#
#          Lng Hotel Name
# 2   -45.4264
# 6   -62.9967
# 10   57.7575
# 12  -67.1856
# 13  115.3333
# 14  113.6333
# 17  -90.3518
# 18  -63.2167
# 19 -139.0333
# 20  -10.0467

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
 
    hotels = requests.get(base_url, params=params).json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
    except (IndexError):
        print("Cannot find hotel...skipping.")
# Out:
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.
# Cannot find hotel...skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
drop_hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!='')]
drop_hotel_df.head()
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 2             Formiga      BR     65.17    scattered clouds -20.4644
# 6              Viedma      AR     67.93     overcast clouds -40.8135
# 10    Bambous Virieux      MU     75.45    scattered clouds -20.3428
# 12  Placido De Castro      BR     74.46     overcast clouds -10.3353
# 13          Busselton      AU     68.56          light rain -33.6500
#
#          Lng               Hotel Name
# 2   -45.4264       Victor Plaza Hotel
# 6   -62.9967            Hotel Cristal
# 10   57.7575           Casa Tia Villa
# 12  -67.1856            Hotel Carioca
# 13  115.3333  Observatory Guest House

# %%
# 8a. Create the output File (CSV)
output_data_file = "/Users/user/Desktop/Vacation_Search/WeatherPy_Vacation.csv"
# 8b. Export the City_Data into a csv
drop_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in drop_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = drop_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
